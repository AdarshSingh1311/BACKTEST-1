# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta,TH
import warnings
warnings.filterwarnings('ignore')
# !pip install opstrat
import opstrat as op
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import ta
import pandas_ta as ta
from mpl_toolkits import mplot3d
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score


from breeze_connect import BreezeConnect

# Initialize SDK
breeze = BreezeConnect(api_key="f65&396497Vq0161W2d18ngV35%5755@")

# Obtain your session key from https://api.icicidirect.com/apiuser/login?api_key=YOUR_API_KEY
# Incase your api-key has special characters(like +,=,!) then encode the api key before using in the url as shown below.
import urllib
print("https://api.icicidirect.com/apiuser/login?api_key="+urllib.parse.quote_plus("your_api_key"))

# Generate Session
breeze.generate_session(api_secret="5l88!0708cJ04~74!X1V71a90j4~392+",
                        session_token="14065394")
# Out:
# ...
# https://api.icicidirect.com/apiuser/login?api_key=your_api_key

# %%
n = breeze.get_historical_data_v2(interval="1day",
                            from_date= "2023-01-01T07:00:00.000Z",
                            to_date= "2023-06-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
m =pd.DataFrame(n['Success'])
m.index = m.datetime
m.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
m.rename( {'datetime' : 'date'} , inplace = True)
m['Expiry'] = 0
for i in range (len(m)) :
    m['Expiry'].iloc[i] = pd.to_datetime(m.index[i]).date() + relativedelta( weekday=TH(+1))
    m['weekday'] = pd.to_datetime(m['Expiry'][i]).weekday()
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 7>()
#       1 n = breeze.get_historical_data_v2(interval="1day",
#       2                             from_date= "2023-01-01T07:00:00.000Z",
#       3                             to_date= "2023-06-30T07:00:00.000Z",
#       4                             stock_code="NIFTY",
#       5                             exchange_code="NSE",
#       6                             product_type="cash")
# ----> 7 m =pd.DataFrame(n['Success'])
#       8 m.index = m.datetime
#       9 m.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
#
# KeyError: 'Success'

# %%
import pandas_ta as ta
n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-05-01T07:00:00.000Z",
                            to_date= "2023-05-16T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t =pd.DataFrame(n['Success'])
t['buy_signal'] = 0
t['sell_signal'] = 0
t.index = t.datetime
t.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t.rename( {'datetime' : 'date'} , inplace = True)


t = t[1:]
#print(t)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-05-16T07:00:00.000Z",
                            to_date= "2023-05-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t11 =pd.DataFrame(n['Success'])
t11['buy_signal'] = 0
t11['sell_signal'] = 0
t11.index = t11.datetime
t11.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t11.rename( {'datetime' : 'date'} , inplace = True)
t11 = t11[1:]
#print(t11)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-06-01T07:00:00.000Z",
                            to_date= "2023-06-20T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t22 =pd.DataFrame(n['Success'])
t22['buy_signal'] = 0
t22['sell_signal'] = 0
t22.index = t22.datetime
t22.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t22.rename( {'datetime' : 'date'} , inplace = True)
t22 = t22[1:]
#print(t22)


n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-06-20T07:00:00.000Z",
                            to_date= "2023-06-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t33 =pd.DataFrame(n['Success'])
t33['buy_signal'] = 0
t33['sell_signal'] = 0
t33.index = t33.datetime
t33.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t33.rename( {'datetime' : 'date'} , inplace = True)
t33 = t33[1:]
#print(t33)


n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-04-17T07:00:00.000Z",
                            to_date= "2023-04-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t44 =pd.DataFrame(n['Success'])
t44['buy_signal'] = 0
t44['sell_signal'] = 0
t44.index = t44.datetime
t44.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t44.rename( {'datetime' : 'date'} , inplace = True)

t44 = t44[1:]
#print(t44)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-04-01T07:00:00.000Z",
                            to_date= "2023-04-17T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t77 =pd.DataFrame(n['Success'])
t77['buy_signal'] = 0
t77['sell_signal'] = 0
t77.index = t77.datetime
t77.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t77.rename( {'datetime' : 'date'} , inplace = True)

t77 = t77[1:]
#print(t77)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-03-15T07:00:00.000Z",
                            to_date= "2023-03-31T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t66 =pd.DataFrame(n['Success'])
t66['buy_signal'] = 0
t66['sell_signal'] = 0
t66.index = t66.datetime
t66.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t66.rename( {'datetime' : 'date'} , inplace = True)

t66 = t66[1:]
#print(t66)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-03-01T07:00:00.000Z",
                            to_date= "2023-03-15T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t55 =pd.DataFrame(n['Success'])
t55['buy_signal'] = 0
t55['sell_signal'] = 0
t55.index = t55.datetime
t55.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t55.rename( {'datetime' : 'date'} , inplace = True)


t55 = t55[1:]
#print(t55)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-02-15T07:00:00.000Z",
                            to_date= "2023-02-28T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t88 =pd.DataFrame(n['Success'])
t88['buy_signal'] = 0
t88['sell_signal'] = 0
t88.index = t88.datetime
t88.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t88.rename( {'datetime' : 'date'} , inplace = True)


t88 = t88[1:]
#print(t88)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-02-01T07:00:00.000Z",
                            to_date= "2023-02-15T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t99 =pd.DataFrame(n['Success'])
t99['buy_signal'] = 0
t99['sell_signal'] = 0
t99.index = t99.datetime
t99.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t99.rename( {'datetime' : 'date'} , inplace = True)

t99 = t99[1:]
#print(t99)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-01-15T07:00:00.000Z",
                            to_date= "2023-01-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t1010 =pd.DataFrame(n['Success'])
t1010['buy_signal'] = 0
t1010['sell_signal'] = 0
t1010.index = t1010.datetime
t1010.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t1010.rename( {'datetime' : 'date'} , inplace = True)

t1010 = t1010[1:]
#print(t1010)

n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-01-01T07:00:00.000Z",
                            to_date= "2023-01-16T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t1111 =pd.DataFrame(n['Success'])
t1111['buy_signal'] = 0
t1111['sell_signal'] = 0
t1111.index = t1111.datetime
t1111.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t1111.rename( {'datetime' : 'date'} , inplace = True)

t1111 = t1111[1:]
t = pd.concat([t1111 ,t1010 ,t99 ,t88 ,t55 , t66 ,t77 ,t44 ,t , t11 , t22 , t33])
t['ADX'] = 0
t['supertrend'] = ta.supertrend(high = t['high'] , low = t['low'] , close = t['close'] , period = 7 , multiplier = 3)['SUPERT_7_3.0']
t['ADX'] = ta.adx(high = t['high'] , low = t['low'] , close = t['close'] ,length = 7 )['ADX_7']
t.dropna(inplace = True)
for i in range (len(t)):
    if (t['close'].iloc[i-1]<t['supertrend'].iloc[i-1]) & (t['close'].iloc[i]>t['supertrend'].iloc[i]) :
        t['buy_signal'].iloc[i] = 1
    if (t['close'].iloc[i-1]>t['supertrend'].iloc[i-1]) & (t['close'].iloc[i]<t['supertrend'].iloc[i]) :
        t['sell_signal'].iloc[i] = -1  
t['signal'] = np.where(t['close']>t['supertrend'],1 , np.nan)  
t['signal'] = np.where(t['close']<t['supertrend'],-1 , t['signal'])    
t['supb'] = np.where(t['signal'] == 1 , t['supertrend'] , np.nan)
t['sups'] = np.where(t['signal'] == -1 , t['supertrend'] , np.nan)

t= t[1:]
t

# %%
n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-05-01T07:00:00.000Z",
                            to_date= "2023-05-16T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t1 =pd.DataFrame(n['Success'])
t1['buy_signal'] = 0
t1['sell_signal'] = 0
t1.index = t1.datetime
t1.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t1.rename( {'datetime' : 'date'} , inplace = True)


t1= t1[1:]
#print(t)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-05-16T07:00:00.000Z",
                            to_date= "2023-05-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t111 =pd.DataFrame(n['Success'])
t111['buy_signal'] = 0
t111['sell_signal'] = 0
t111.index = t111.datetime
t111.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t111.rename( {'datetime' : 'date'} , inplace = True)
t111 = t111[1:]
#print(t11)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-06-01T07:00:00.000Z",
                            to_date= "2023-06-20T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t122 =pd.DataFrame(n['Success'])
t122['buy_signal'] = 0
t122['sell_signal'] = 0
t122.index = t122.datetime
t122.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t122.rename( {'datetime' : 'date'} , inplace = True)
t122 = t122[1:]
#print(t22)


n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-06-20T07:00:00.000Z",
                            to_date= "2023-06-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t133 =pd.DataFrame(n['Success'])
t133['buy_signal'] = 0
t133['sell_signal'] = 0
t133.index = t133.datetime
t133.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t133.rename( {'datetime' : 'date'} , inplace = True)
t133 = t133[1:]
#print(t33)


n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-04-17T07:00:00.000Z",
                            to_date= "2023-04-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t144 =pd.DataFrame(n['Success'])
t144['buy_signal'] = 0
t144['sell_signal'] = 0
t144.index = t144.datetime
t144.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t144.rename( {'datetime' : 'date'} , inplace = True)

t144 = t144[1:]
#print(t44)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-04-01T07:00:00.000Z",
                            to_date= "2023-04-17T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t177 =pd.DataFrame(n['Success'])
t177['buy_signal'] = 0
t177['sell_signal'] = 0
t177.index = t177.datetime
t177.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t177.rename( {'datetime' : 'date'} , inplace = True)

t177 = t177[1:]
#print(t77)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-03-15T07:00:00.000Z",
                            to_date= "2023-03-31T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t166 =pd.DataFrame(n['Success'])
t166['buy_signal'] = 0
t166['sell_signal'] = 0
t166.index = t166.datetime
t166.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t166.rename( {'datetime' : 'date'} , inplace = True)

t166 = t166[1:]
#print(t66)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-03-01T07:00:00.000Z",
                            to_date= "2023-03-15T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t155 =pd.DataFrame(n['Success'])
t155['buy_signal'] = 0
t155['sell_signal'] = 0
t155.index = t155.datetime
t155.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t155.rename( {'datetime' : 'date'} , inplace = True)


t155 = t155[1:]
#print(t55)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-02-15T07:00:00.000Z",
                            to_date= "2023-02-28T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t188 =pd.DataFrame(n['Success'])
t188['buy_signal'] = 0
t188['sell_signal'] = 0
t188.index = t188.datetime
t188.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t188.rename( {'datetime' : 'date'} , inplace = True)


t188 = t188[1:]
#print(t88)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-02-01T07:00:00.000Z",
                            to_date= "2023-02-15T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t199 =pd.DataFrame(n['Success'])
t199['buy_signal'] = 0
t199['sell_signal'] = 0
t199.index = t199.datetime
t199.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t199.rename( {'datetime' : 'date'} , inplace = True)

t199 = t199[1:]
#print(t99)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-01-15T07:00:00.000Z",
                            to_date= "2023-01-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t11010 =pd.DataFrame(n['Success'])
t11010['buy_signal'] = 0
t11010['sell_signal'] = 0
t11010.index = t11010.datetime
t11010.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t11010.rename( {'datetime' : 'date'} , inplace = True)

t11010 = t11010[1:]
#print(t1010)

n = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-01-01T07:00:00.000Z",
                            to_date= "2023-01-16T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t11111 =pd.DataFrame(n['Success'])
t11111['buy_signal'] = 0
t11111['sell_signal'] = 0
t11111.index = t11111.datetime
t11111.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t11111.rename( {'datetime' : 'date'} , inplace = True)

t11111 = t11111[1:]
t1 = pd.concat([t11111 ,t11010 ,t199 ,t188 ,t155 , t166 ,t177 ,t144 ,t1 , t111 , t122 , t133])
t1['ADX'] = 0
t1['supertrend'] = ta.supertrend(high = t1['high'] , low = t1['low'] , close = t1['close'] , period = 7 , multiplier = 3)['SUPERT_7_3.0']
t1['ADX'] = ta.adx(high = t1['high'] , low = t1['low'] , close = t1['close'] ,length = 7 )['ADX_7']
t1.dropna(inplace = True)
for i in range (len(t1)):
    if (t1['close'].iloc[i-1]<t1['supertrend'].iloc[i-1]) & (t1['close'].iloc[i]>t1['supertrend'].iloc[i]) :
        t1['buy_signal'].iloc[i] = 1
    if (t1['close'].iloc[i-1]>t1['supertrend'].iloc[i-1]) & (t1['close'].iloc[i]<t1['supertrend'].iloc[i]) :
        t1['sell_signal'].iloc[i] = -1  
t1['signal'] = np.where(t1['close']>t1['supertrend'],1 , np.nan)  
t1['signal'] = np.where(t1['close']<t1['supertrend'],-1 , t1['signal'])    
t1['supb'] = np.where(t1['signal'] == 1 , t1['supertrend'] , np.nan)
t1['sups'] = np.where(t1['signal'] == -1 , t1['supertrend'] , np.nan)

t1= t1[1:]
t1

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
fig = go.Figure()
fig.add_trace(go.Candlestick(x = t.index ,
                             open = t.open,
                             high = t.high ,
                             low = t.low ,
                             close = t.close , name = 'market data') )
fig.add_trace(go.Scatter(x= t.index , y = t.supb  , line = dict( color = 'green' , width = 1) , name = 'supb'))
fig.add_trace(go.Scatter(x= t.index , y = t.sups  , line = dict( color = 'red' , width = 1) , name = 'sups'))
fig.show()

# %%
s =  "2023-06-08T07:00:00.000Z" 
ss =  "2023-06-09T07:00:00.000Z"
ni = breeze.get_historical_data_v2(interval="5minute",
                            from_date= s ,   
                            to_date = ss  ,         
                            stock_code="NIFTY",
                            exchange_code="NSE", 
                            product_type="cash")
nifty_intraday =pd.DataFrame(ni['Success'])
nifty_intraday.index = nifty_intraday.datetime
nifty_intraday.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume'  }  , inplace = True)
nifty_intraday.rename( {'datetime' : 'date'} , inplace = True)
nifty_intraday['signal'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].signal
nifty_intraday['supb'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].supb
nifty_intraday['sups'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].sups
nifty_intraday['ADX'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].ADX
nifty_intraday

# %%
ni = breeze.get_historical_data_v2(interval="30minute",
                            from_date= s ,   
                            to_date = ss  ,         
                            stock_code="NIFTY",
                            exchange_code="NSE", 
                            product_type="cash")
nifty_intraday1 =pd.DataFrame(ni['Success'])
nifty_intraday1.index = nifty_intraday1.datetime
nifty_intraday1.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume'  }  , inplace = True)
nifty_intraday1.rename( {'datetime' : 'date'} , inplace = True)
nifty_intraday1['signal'] = t1[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].signal
nifty_intraday1['supb'] = t1[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].supb
nifty_intraday1['sups'] = t1[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].sups
nifty_intraday1

# %%
from datetime import datetime
from datetime import timedelta
a =datetime.strptime(nifty_intraday.index[0][11:16],'%H:%M')
delta = timedelta(minutes=5)
#nifty_intraday.index[0][11:16]
a =a- delta
a = a.time()
str(a)

# %%
nifty_intraday['cand'] = 0
nifty_intraday['ref'] = 0
nifty_intraday['buy'] = 0
nifty_intraday['sell'] = 0
nifty_intraday['trade'] = 0
nifty_intraday['buy_'] = 0
nifty_intraday['sell_'] = 0
sl = 0
total_p = []
buy_pr = []
sell_pr = []
pos = 0
tradereport = []
cols = ['Time' , 'up_down', 'htf_updwn', 'dist_suptrnd' , 'cand_str' , 'opt_pr' , 'ADX' ' Label'] 
time = 0
for i in range (len(nifty_intraday) ):
    if nifty_intraday['close'].iloc[i] > nifty_intraday['open'].iloc[i] :
        nifty_intraday['cand'].iloc[i] = 1
    if nifty_intraday['close'].iloc[i] < nifty_intraday['open'].iloc[i] :
        nifty_intraday['cand'].iloc[i] = -1    
    if (nifty_intraday['signal'].iloc[i] == 1)  & (nifty_intraday['cand'].iloc[i] == -1) & (nifty_intraday['low'].iloc[i] >nifty_intraday['supb'].iloc[i]) :
        nifty_intraday['ref'].iloc[i] = 1
    if (nifty_intraday['signal'].iloc[i] == -1)  & (nifty_intraday['cand'].iloc[i] == 1) & (nifty_intraday['high'].iloc[i]< nifty_intraday['sups'].iloc[i]) :
        nifty_intraday['ref'].iloc[i] = -1 
    
    if (nifty_intraday['ref'].iloc[i-1] == 1)  &  (nifty_intraday['close'].iloc[i] > nifty_intraday['high'].iloc[i-1]) : 
        nifty_intraday['buy'].iloc[i] = nifty_intraday['close'].iloc[i]
        #nifty_intraday['trade'].iloc[i] = 1
    if (nifty_intraday['ref'].iloc[i-1] == -1)  & (nifty_intraday['close'].iloc[i] < nifty_intraday['low'].iloc[i-1])  :
        nifty_intraday['sell'].iloc[i] = nifty_intraday['close'].iloc[i] 
        #nifty_intraday['trade'].iloc[i] = -1
        
    if (nifty_intraday['buy'].iloc[i] == nifty_intraday['close'].iloc[i]) & (pos == 0 )  :
        if nifty_intraday['low'].iloc[i] < nifty_intraday['low'].iloc[i-1] :
            sl = nifty_intraday['low'].iloc[i]
        if nifty_intraday['low'].iloc[i] > nifty_intraday['low'].iloc[i-1] :
            sl = nifty_intraday['low'].iloc[i-1] 
        nifty_intraday['trade'].iloc[i] = 1 
        atm_strike_b = (50*round(nifty_intraday['close'].iloc[i]/50) )
        s1 = s[0:10] + ' 00:00:00'
        ex = m[m.index == s1].Expiry[0]
        i11 = breeze.get_historical_data_v2(interval="5minute",
                            from_date = s ,
                            to_date =  ss ,
                            stock_code="NIFTY",
                            exchange_code="NFO",
                            product_type="options",
                            expiry_date= ex ,
                            right="call",
                            strike_price=atm_strike_b)
        o=pd.DataFrame(i11['Success'])
        buy_pr.append(o.close.iloc[i-2])
        pos = 1
        sl_o = o.close.iloc[i-3]
        time_ = nifty_intraday.index[i][11:16]
        up_down = nifty_intraday['signal'].iloc[i]
        jj = 0
        if np.shape(nifty_intraday1[ nifty_intraday1.index == nifty_intraday.index[i] ] )[0] == 0 :
            jj = 0
            while np.shape(nifty_intraday1[ nifty_intraday1.index == str( (datetime.strptime(nifty_intraday.index[i][11:16],'%H:%M' ) - timedelta(minutes= 5 +jj)).time() ) ])[0] == 1 :
                jj = jj +5
                
        g = str( ( datetime.strptime(nifty_intraday.index[i][11:16],'%H:%M' ) - timedelta(minutes= 5 +jj) ).time())     
        htf_updown = nifty_intraday1[nifty_intraday1.index == g] ['signal']
        dist_suptrnd = (nifty_intraday['close'].iloc[i] - nifty_intraday['sups'].iloc[i]) / nifty_intraday['close'].iloc[i] 
        cand_str = (nifty_intraday['close'].iloc[i] - nifty_intraday['open'].iloc[i])/nifty_intraday['close'].iloc[i]
        opt_pr = o.close.iloc[i-2] / nifty_intraday['close'].iloc[i]
        adx = nifty_intraday['ADX'].iloc[i]
        opt_pr_buy = o.close.iloc[i-2]
        
    if (nifty_intraday['sell'].iloc[i] == nifty_intraday['close'].iloc[i]) & (pos == 0 )  :
        if nifty_intraday['high'].iloc[i] > nifty_intraday['high'].iloc[i-1] :
            sl = nifty_intraday['high'].iloc[i]
        if nifty_intraday['high'].iloc[i] < nifty_intraday['high'].iloc[i-1] :
            sl = nifty_intraday['high'].iloc[i-1]
        nifty_intraday['trade'].iloc[i] = -1 
        atm_strike_s = (50*round(nifty_intraday['close'].iloc[i]/50) )
        d1 = s[0:10] + ' 00:00:00'
        ex = m[m.index == d1].Expiry[0]
        i11 = breeze.get_historical_data_v2(interval="5minute",
                            from_date = s ,
                            to_date =  ss ,
                            stock_code="NIFTY",
                            exchange_code="NFO",
                            product_type="options",
                            expiry_date= ex ,
                            right="put",
                            strike_price=atm_strike_s)
        l=pd.DataFrame(i11['Success'])
        buy_pr.append(l.close.iloc[i-2])
        pos = -1    
        sl_o = l.close.iloc[i-3]
        time_ = nifty_intraday.index[i][11:16]
        up_down = nifty_intraday['signal'].iloc[i]
        jj = 0
        if np.shape(nifty_intraday1[ nifty_intraday1.index == nifty_intraday.index[i] ] )[0] == 0 :
            jj = 0
            while np.shape(nifty_intraday1[ nifty_intraday1.index == str( (datetime.strptime(nifty_intraday.index[i][11:16],'%H:%M' ) - timedelta(minutes= 5 +jj)).time() ) ])[0] == 1 :
                jj = jj +5
                
        g = str( ( datetime.strptime(nifty_intraday.index[i][11:16],'%H:%M' ) - timedelta(minutes= 5 +jj) ).time()) 
        htf_updown = nifty_intraday1[nifty_intraday1.index == g] ['signal']
        dist_suptrnd = (nifty_intraday['sups'].iloc[i] - nifty_intraday['close'].iloc[i]) / nifty_intraday['close'].iloc[i]
        cand_str = (nifty_intraday['open'].iloc[i] - nifty_intraday['close'].iloc[i])/nifty_intraday['close'].iloc[i]
        opt_pr = o.close.iloc[i-2] / nifty_intraday['close'].iloc[i]
        adx = nifty_intraday['ADX'].iloc[i]
        opt_pr_buy = o.close.iloc[i-2]
        print( nifty_intraday['sups'].iloc[i]  )
    if pos == 1 :
        #if (nifty_intraday['close'].iloc[i] < sl) :
        if o.close.iloc[i-2] > (0.2*sl_o + sl_o) :
            sl_o = sl_o + 0.15*sl_o
        if (o.close.iloc[i-2] < sl_o) :
            nifty_intraday['trade'].iloc[i] = -1
            sell_pr.append(o.close.iloc[i-2])
            pos = 0
            if (o.close.iloc[i-2] > opt_pr_buy) :
                lebel = 1
            else :
                label = 0
            tradereport.append([time_,up_down,htf_updown , dist_suptrnd,cand_str,opt_pr,adx])    
    if pos == -1 :
        #if (nifty_intraday['close'].iloc[i] > sl) :
        if l.close.iloc[i-2] < (0.2*sl_o - sl_o) :
            sl_o = sl_o -  0.15*sl_o
        if (l.close.iloc[i-2] > sl_o) :
            nifty_intraday['trade'].iloc[i] = 1
            sell_pr.append(l.close.iloc[i-2])
            pos = 0 
            if (o.close.iloc[i-2] > opt_pr_buy) :
                label = 1
            else :
                label = 0
            tradereport.append([time_,up_down,htf_updown , dist_suptrnd,cand_str,opt_pr,adx])     
    if ( pos == 1)  & (nifty_intraday.index[i] == (s[0:10] + ' 15:25:00') ) : 
        sell_pr.append(o.close.iloc[i-2])
    if ( pos == -1)  & (nifty_intraday.index[i] == (s[0:10] + ' 15:25:00') ) : 
        sell_pr.append(l.close.iloc[i-2])  
        
            
            
nifty_intraday['buy'] = np.where(nifty_intraday['buy'] == 0 , np.nan , nifty_intraday['buy'])
nifty_intraday['sell'] = np.where(nifty_intraday['sell'] == 0 , np.nan , nifty_intraday['sell'])  
nifty_intraday['trade'] = np.where(nifty_intraday['trade'] == 0 , np.nan , nifty_intraday['trade'])
for i in range (len(nifty_intraday)):
    if nifty_intraday['trade'].iloc[i] == 1 :
        nifty_intraday['buy_'].iloc[i] = nifty_intraday['close'].iloc[i]
    if nifty_intraday['trade'].iloc[i] == -1 :
        nifty_intraday['sell_'].iloc[i] = nifty_intraday['close'].iloc[i]
nifty_intraday['buy_'] = np.where(nifty_intraday['buy_'] == 0 , np.nan , nifty_intraday['buy_'])
nifty_intraday['sell_'] = np.where(nifty_intraday['sell_'] == 0 , np.nan , nifty_intraday['sell_'])      
print(nifty_intraday)
print(buy_pr)
print(sell_pr)
print(l.close.iloc[39])
print(time_)
#print(l)

for i in range (len(buy_pr)):
    p = (sell_pr[i]*50) - (buy_pr[i]*50)
    total_p.append(p)
    c = (buy_pr[i]*50)
    print(f' Trade {i+1} : Capital = {10*c} Profit = {10*p} ' )
    print(f' Total Intraday Profit = {10*np.array(total_p).sum()} ' )
    rr =pd.DataFrame(tradereport , columns = cols)
    print(rr)

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(x = nifty_intraday.index ,
                             open = nifty_intraday.open,
                             high = nifty_intraday.high ,
                             low = nifty_intraday.low ,
                             close = nifty_intraday.close , name = 'market data'))
fig.add_trace(go.Scatter(x= nifty_intraday.index , y = nifty_intraday.supb  , line = dict( color = 'green' , width = 1) , name = 'supb'))
fig.add_trace(go.Scatter(x= nifty_intraday.index , y = nifty_intraday.sups  , line = dict( color = 'red' , width = 1) , name = 'sups'))
fig.add_scatter (x = nifty_intraday.index , y= nifty_intraday.buy_ , mode = "markers" ,marker = dict(size = 7, color = "yellow") , name ="buy" ) 
fig.add_scatter (x = nifty_intraday.index , y= nifty_intraday.sell_ , mode = "markers" ,marker = dict(size = 7, color = "blue") , name ="sell" ) 
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(x = nifty_intraday1.index ,
                             open = nifty_intraday1.open,
                             high = nifty_intraday1.high ,
                             low = nifty_intraday1.low ,
                             close = nifty_intraday1.close , name = 'market data'))
fig.add_trace(go.Scatter(x= nifty_intraday1.index , y = nifty_intraday1.supb  , line = dict( color = 'green' , width = 1) , name = 'supb'))
fig.add_trace(go.Scatter(x= nifty_intraday1.index , y = nifty_intraday1.sups  , line = dict( color = 'red' , width = 1) , name = 'sups'))
#fig.add_scatter (x = nifty_intraday1.index , y= nifty_intraday1.buy_ , mode = "markers" ,marker = dict(size = 7, color = "yellow") , name ="buy" ) 
#fig.add_scatter (x = nifty_intraday1.index , y= nifty_intraday1.sell_ , mode = "markers" ,marker = dict(size = 7, color = "blue") , name ="sell" ) 
fig.show()

# %%
def reloop (i) :
    try :
        s =  m.index[i][0:10] + "T07:00:00.000Z" 
        ss =  m.index[i+1][0:10] + "T07:00:00.000Z"
        ni = breeze.get_historical_data_v2(interval="5minute",
                                from_date= s ,   
                                to_date = ss  ,         
                                stock_code="NIFTY",
                                exchange_code="NSE", 
                                product_type="cash")
        nifty_intraday =pd.DataFrame(ni['Success'])
        nifty_intraday.index = nifty_intraday.datetime
        nifty_intraday.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume'  }  , inplace = True)
        nifty_intraday.rename( {'datetime' : 'date'} , inplace = True)
        nifty_intraday['signal'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].signal
        nifty_intraday['supb'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].supb
        nifty_intraday['sups'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].sups



        nifty_intraday['cand'] = 0
        nifty_intraday['ref'] = 0
        nifty_intraday['buy'] = 0
        nifty_intraday['sell'] = 0
        nifty_intraday['trade'] = 0
        nifty_intraday['buy_'] = 0
        nifty_intraday['sell_'] = 0
        sl = 0
        total_p = []
        buy_pr = []
        sell_pr = []
        pos = 0
        for i in range (len(nifty_intraday) ):
            if nifty_intraday['close'].iloc[i] > nifty_intraday['open'].iloc[i] :
                nifty_intraday['cand'].iloc[i] = 1
            if nifty_intraday['close'].iloc[i] < nifty_intraday['open'].iloc[i] :
                nifty_intraday['cand'].iloc[i] = -1    
            if (nifty_intraday['signal'].iloc[i] == 1)  & (nifty_intraday['cand'].iloc[i] == -1) & (nifty_intraday['low'].iloc[i] >nifty_intraday['supb'].iloc[i]) :
                nifty_intraday['ref'].iloc[i] = 1
            if (nifty_intraday['signal'].iloc[i] == -1)  & (nifty_intraday['cand'].iloc[i] == 1) & (nifty_intraday['high'].iloc[i]< nifty_intraday['sups'].iloc[i]) :
                nifty_intraday['ref'].iloc[i] = -1 

            if (nifty_intraday['ref'].iloc[i-1] == 1)  &  (nifty_intraday['close'].iloc[i] > nifty_intraday['high'].iloc[i-1]) : 
                nifty_intraday['buy'].iloc[i] = nifty_intraday['close'].iloc[i]
                #nifty_intraday['trade'].iloc[i] = 1
            if (nifty_intraday['ref'].iloc[i-1] == -1)  & (nifty_intraday['close'].iloc[i] < nifty_intraday['low'].iloc[i-1])  :
                nifty_intraday['sell'].iloc[i] = nifty_intraday['close'].iloc[i] 
                #nifty_intraday['trade'].iloc[i] = -1

            if (nifty_intraday['buy'].iloc[i] == nifty_intraday['close'].iloc[i]) & (pos == 0 )  :
                if nifty_intraday['low'].iloc[i] < nifty_intraday['low'].iloc[i-1] :
                    sl = nifty_intraday['low'].iloc[i]
                if nifty_intraday['low'].iloc[i] > nifty_intraday['low'].iloc[i-1] :
                    sl = nifty_intraday['low'].iloc[i-1] 
                nifty_intraday['trade'].iloc[i] = 1 
                atm_strike_b = (50*round(nifty_intraday['close'].iloc[i]/50) )
                s1 = s[0:10] + ' 00:00:00'
                ex = m[m.index == s1].Expiry[0]
                i11 = breeze.get_historical_data_v2(interval="5minute",
                                from_date = s ,
                                to_date =  ss ,
                                stock_code="NIFTY",
                                exchange_code="NFO",
                                product_type="options",
                                expiry_date= ex ,
                                right="call",
                                strike_price=atm_strike_b)
                o=pd.DataFrame(i11['Success'])
                buy_pr.append(o.close.iloc[i-2])
                pos = 1
                sl_o = o.close.iloc[i-3]
                

            if (nifty_intraday['sell'].iloc[i] == nifty_intraday['close'].iloc[i]) & (pos == 0 )  :
                if nifty_intraday['high'].iloc[i] > nifty_intraday['high'].iloc[i-1] :
                    sl = nifty_intraday['high'].iloc[i]
                if nifty_intraday['high'].iloc[i] < nifty_intraday['high'].iloc[i-1] :
                    sl = nifty_intraday['high'].iloc[i-1]
                nifty_intraday['trade'].iloc[i] = -1 
                atm_strike_s = (50*round(nifty_intraday['close'].iloc[i]/50) )
                d1 = s[0:10] + ' 00:00:00'
                ex = m[m.index == d1].Expiry[0]
                i11 = breeze.get_historical_data_v2(interval="5minute",
                                from_date = s ,
                                to_date =  ss ,
                                stock_code="NIFTY",
                                exchange_code="NFO",
                                product_type="options",
                                expiry_date= ex ,
                                right="put",
                                strike_price=atm_strike_s)
                l=pd.DataFrame(i11['Success'])
                buy_pr.append(l.close.iloc[i-2])
                pos = -1    
                sl_o = l.close.iloc[i-3]


            if pos == 1 :
                #if (nifty_intraday['close'].iloc[i] < sl) :
                if o.close.iloc[i-2] > (0.2*sl_o + sl_o) :
                    sl_o = sl_o +  0.15*sl_o 
                if o.close.iloc[i-2] < sl_o :
                    nifty_intraday['trade'].iloc[i] = -1
                    sell_pr.append(o.close.iloc[i-2])
                    pos = 0
            if pos == -1 :
                #if (nifty_intraday['close'].iloc[i] > sl) :
                if l.close.iloc[i-2] < (0.2*sl_o - sl_o) :
                    sl_o = sl_o -  0.15*sl_o 
                if l.close.iloc[i-2] > sl_o :
                    nifty_intraday['trade'].iloc[i] = 1
                    sell_pr.append(l.close.iloc[i-2])
                    pos = 0  

            if ( pos == 1)  & (nifty_intraday.index[i] == (s[0:10] + ' 15:25:00') ) : 
                sell_pr.append(o.close.iloc[i-2])
            if ( pos == -1)  & (nifty_intraday.index[i] == (s[0:10] + ' 15:25:00') ) : 
                sell_pr.append(l.close.iloc[i-2])  



        nifty_intraday['buy'] = np.where(nifty_intraday['buy'] == 0 , np.nan , nifty_intraday['buy'])
        nifty_intraday['sell'] = np.where(nifty_intraday['sell'] == 0 , np.nan , nifty_intraday['sell'])  
        nifty_intraday['trade'] = np.where(nifty_intraday['trade'] == 0 , np.nan , nifty_intraday['trade'])
        for i in range (len(nifty_intraday)):
            if nifty_intraday['trade'].iloc[i] == 1 :
                nifty_intraday['buy_'].iloc[i] = nifty_intraday['close'].iloc[i]
            if nifty_intraday['trade'].iloc[i] == -1 :
                nifty_intraday['sell_'].iloc[i] = nifty_intraday['close'].iloc[i]
        nifty_intraday['buy_'] = np.where(nifty_intraday['buy_'] == 0 , np.nan , nifty_intraday['buy_'])
        nifty_intraday['sell_'] = np.where(nifty_intraday['sell_'] == 0 , np.nan , nifty_intraday['sell_'])      
        #print(nifty_intraday)
        #print(buy_pr)
        #print(sell_pr)
        #print(l.close.iloc[50])
        for i in range (len(buy_pr)):
            p = (sell_pr[i]*50) - (buy_pr[i]*50)
            total_p.append(p)
            c = (buy_pr[i]*50)
            #print(f' Trade {i+1} : Capital = {10*c} Profit = {10*p} ' )
            #print(f' Total Intraday Profit = {10*np.array(total_p).sum()} ' )
        ip.append(10*np.array(total_p).sum() ) 
        print(10*np.array(total_p).sum())

    except IndexError :
        ip.append(0)
        print(0)
    
    except ValueError :
        ip.append(0)
        print(0)
    except (AttributeError) :
        ip.append(0)
        print(0) 
    except json.decoder.JSONDecodeError:
        ip.append(0)
        print(0) 
    
    except Exception :
        #ip.append(0)
        #print(0) 
        reloop(i)
        
    #except ( get_historical_data_v2() Error) :
    #    ip.append(0)
    #    print(0)
    
reloop(6)

# %%
import json
ip = []
for i in range (len(m)-1):
    try :
        s =  m.index[i][0:10] + "T07:00:00.000Z" 
        ss =  m.index[i+1][0:10] + "T07:00:00.000Z"
        ni = breeze.get_historical_data_v2(interval="5minute",
                                from_date= s ,   
                                to_date = ss  ,         
                                stock_code="NIFTY",
                                exchange_code="NSE", 
                                product_type="cash")
        nifty_intraday =pd.DataFrame(ni['Success'])
        nifty_intraday.index = nifty_intraday.datetime
        nifty_intraday.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume'  }  , inplace = True)
        nifty_intraday.rename( {'datetime' : 'date'} , inplace = True)
        nifty_intraday['signal'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].signal
        nifty_intraday['supb'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].supb
        nifty_intraday['sups'] = t[s[0:10] + ' 09:15:00' : s[0:10] + ' 15:25:00'].sups



        nifty_intraday['cand'] = 0
        nifty_intraday['ref'] = 0
        nifty_intraday['buy'] = 0
        nifty_intraday['sell'] = 0
        nifty_intraday['trade'] = 0
        nifty_intraday['buy_'] = 0
        nifty_intraday['sell_'] = 0
        sl = 0
        total_p = []
        buy_pr = []
        sell_pr = []
        pos = 0
        for i in range (len(nifty_intraday) ):
            if nifty_intraday['close'].iloc[i] > nifty_intraday['open'].iloc[i] :
                nifty_intraday['cand'].iloc[i] = 1
            if nifty_intraday['close'].iloc[i] < nifty_intraday['open'].iloc[i] :
                nifty_intraday['cand'].iloc[i] = -1    
            if (nifty_intraday['signal'].iloc[i] == 1)  & (nifty_intraday['cand'].iloc[i] == -1) & (nifty_intraday['low'].iloc[i] >nifty_intraday['supb'].iloc[i]) :
                nifty_intraday['ref'].iloc[i] = 1
            if (nifty_intraday['signal'].iloc[i] == -1)  & (nifty_intraday['cand'].iloc[i] == 1) & (nifty_intraday['high'].iloc[i]< nifty_intraday['sups'].iloc[i]) :
                nifty_intraday['ref'].iloc[i] = -1 

            if (nifty_intraday['ref'].iloc[i-1] == 1)  &  (nifty_intraday['close'].iloc[i] > nifty_intraday['high'].iloc[i-1]) : 
                nifty_intraday['buy'].iloc[i] = nifty_intraday['close'].iloc[i]
                #nifty_intraday['trade'].iloc[i] = 1
            if (nifty_intraday['ref'].iloc[i-1] == -1)  & (nifty_intraday['close'].iloc[i] < nifty_intraday['low'].iloc[i-1])  :
                nifty_intraday['sell'].iloc[i] = nifty_intraday['close'].iloc[i] 
                #nifty_intraday['trade'].iloc[i] = -1

            if (nifty_intraday['buy'].iloc[i] == nifty_intraday['close'].iloc[i]) & (pos == 0 )  :
                if nifty_intraday['low'].iloc[i] < nifty_intraday['low'].iloc[i-1] :
                    sl = nifty_intraday['low'].iloc[i]
                if nifty_intraday['low'].iloc[i] > nifty_intraday['low'].iloc[i-1] :
                    sl = nifty_intraday['low'].iloc[i-1] 
                nifty_intraday['trade'].iloc[i] = 1 
                atm_strike_b = (50*round(nifty_intraday['close'].iloc[i]/50) )
                s1 = s[0:10] + ' 00:00:00'
                ex = m[m.index == s1].Expiry[0]
                i11 = breeze.get_historical_data_v2(interval="5minute",
                                from_date = s ,
                                to_date =  ss ,
                                stock_code="NIFTY",
                                exchange_code="NFO",
                                product_type="options",
                                expiry_date= ex ,
                                right="call",
                                strike_price=atm_strike_b)
                o=pd.DataFrame(i11['Success'])
                buy_pr.append(o.close.iloc[i-2])
                pos = 1
                sl_o = o.close.iloc[i-3]
                

            if (nifty_intraday['sell'].iloc[i] == nifty_intraday['close'].iloc[i]) & (pos == 0 )  :
                if nifty_intraday['high'].iloc[i] > nifty_intraday['high'].iloc[i-1] :
                    sl = nifty_intraday['high'].iloc[i]
                if nifty_intraday['high'].iloc[i] < nifty_intraday['high'].iloc[i-1] :
                    sl = nifty_intraday['high'].iloc[i-1]
                nifty_intraday['trade'].iloc[i] = -1 
                atm_strike_s = (50*round(nifty_intraday['close'].iloc[i]/50) )
                d1 = s[0:10] + ' 00:00:00'
                ex = m[m.index == d1].Expiry[0]
                i11 = breeze.get_historical_data_v2(interval="5minute",
                                from_date = s ,
                                to_date =  ss ,
                                stock_code="NIFTY",
                                exchange_code="NFO",
                                product_type="options",
                                expiry_date= ex ,
                                right="put",
                                strike_price=atm_strike_s)
                l=pd.DataFrame(i11['Success'])
                buy_pr.append(l.close.iloc[i-2])
                pos = -1    
                sl_o = l.close.iloc[i-3]


            if pos == 1 :
                #if (nifty_intraday['close'].iloc[i] < sl) :
                if o.close.iloc[i-2] > (0.2*sl_o + sl_o) :
                    sl_o = sl_o +  0.15*sl_o 
                if o.close.iloc[i-2] < sl_o :
                    nifty_intraday['trade'].iloc[i] = -1
                    sell_pr.append(o.close.iloc[i-2])
                    pos = 0
            if pos == -1 :
                #if (nifty_intraday['close'].iloc[i] > sl) :
                if l.close.iloc[i-2] < (0.2*sl_o - sl_o) :
                    sl_o = sl_o -  0.15*sl_o 
                if l.close.iloc[i-2] > sl_o :
                    nifty_intraday['trade'].iloc[i] = 1
                    sell_pr.append(l.close.iloc[i-2])
                    pos = 0  

            if ( pos == 1)  & (nifty_intraday.index[i] == (s[0:10] + ' 15:25:00') ) : 
                sell_pr.append(o.close.iloc[i-2])
            if ( pos == -1)  & (nifty_intraday.index[i] == (s[0:10] + ' 15:25:00') ) : 
                sell_pr.append(l.close.iloc[i-2])  



        nifty_intraday['buy'] = np.where(nifty_intraday['buy'] == 0 , np.nan , nifty_intraday['buy'])
        nifty_intraday['sell'] = np.where(nifty_intraday['sell'] == 0 , np.nan , nifty_intraday['sell'])  
        nifty_intraday['trade'] = np.where(nifty_intraday['trade'] == 0 , np.nan , nifty_intraday['trade'])
        for i in range (len(nifty_intraday)):
            if nifty_intraday['trade'].iloc[i] == 1 :
                nifty_intraday['buy_'].iloc[i] = nifty_intraday['close'].iloc[i]
            if nifty_intraday['trade'].iloc[i] == -1 :
                nifty_intraday['sell_'].iloc[i] = nifty_intraday['close'].iloc[i]
        nifty_intraday['buy_'] = np.where(nifty_intraday['buy_'] == 0 , np.nan , nifty_intraday['buy_'])
        nifty_intraday['sell_'] = np.where(nifty_intraday['sell_'] == 0 , np.nan , nifty_intraday['sell_'])      
        #print(nifty_intraday)
        #print(buy_pr)
        #print(sell_pr)
        #print(l.close.iloc[50])
        for i in range (len(buy_pr)):
            p = (sell_pr[i]*50) - (buy_pr[i]*50)
            total_p.append(p)
            c = (buy_pr[i]*50)
            #print(f' Trade {i+1} : Capital = {10*c} Profit = {10*p} ' )
            #print(f' Total Intraday Profit = {10*np.array(total_p).sum()} ' )
        ip.append(10*np.array(total_p).sum() ) 
        print(10*np.array(total_p).sum())

    except IndexError :
        ip.append(0)
        print(0)
    
    except ValueError :
        ip.append(0)
        print(0)
    except (AttributeError) :
        ip.append(0)
        print(0) 
    except json.decoder.JSONDecodeError:
        ip.append(0)
        print(0) 
    
    except Exception :
        #ip.append(0)
        #print(0) 
        reloop(i)
        
    #except ( get_historical_data_v2() Error) :
    #    ip.append(0)
    #    print(0)
        
ip.append(0)
m['profit intra'] = ip 
m['profit intra'].cumsum().plot()

# %%
m['profit intra'].cumsum()[-1]

# %%
len(m)

# %%
len(m[m['profit intra'] == 0])

# %%
print( f'{round(271225/75000*100) }% ')

# %%
n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-06-01T07:00:00.000Z",
                            to_date= "2023-06-20T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t22 =pd.DataFrame(n['Success'])
t22['buy_signal'] = 0
t22['sell_signal'] = 0
t22.index = t22.datetime
t22.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t22.rename( {'datetime' : 'date'} , inplace = True)
t22 = t22[1:]
t22

# %%
n = breeze.get_historical_data_v2(interval="5minute",
                            from_date= "2023-06-20T07:00:00.000Z",
                            to_date= "2023-06-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t33 =pd.DataFrame(n['Success'])
t33['buy_signal'] = 0
t33['sell_signal'] = 0
t33.index = t33.datetime
t33.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t33.rename( {'datetime' : 'date'} , inplace = True)
t33 = t33[1:]
t33

# %%
n1 = breeze.get_historical_data_v2(interval="30minute",
                            from_date= "2023-05-01T07:00:00.000Z",
                            to_date= "2023-06-30T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash")
t1 =pd.DataFrame(n1['Success'])
t1['buy_signal'] = 0
t1['sell_signal'] = 0
t1.index = t1.datetime
t1.drop( columns = {'datetime' , 'exchange_code' , 'stock_code' , 'volume' }  , inplace = True)
t1.rename( {'datetime' : 'date'} , inplace = True)
t1['supertrend'] = ta.supertrend(high = t1['high'] , low = t1['low'] , close = t1['close'] , period = 7 , multiplier = 3)['SUPERT_7_3.0']
t1.dropna(inplace = True)
for i in range (len(t1)):
    if (t1['close'].iloc[i-1]<t1['supertrend'].iloc[i-1]) & (t1['close'].iloc[i]>t1['supertrend'].iloc[i]) :
        t1['buy_signal'].iloc[i] = 1
    if (t1['close'].iloc[i-1]>t1['supertrend'].iloc[i-1]) & (t1['close'].iloc[i]<t1['supertrend'].iloc[i]) :
        t1['sell_signal'].iloc[i] = -1  
t1['signal'] = np.where(t1['close']>t1['supertrend'],1 , np.nan)  
t1['signal'] = np.where(t1['close']<t1['supertrend'],-1 , t1['signal'])    
t1['supb'] = np.where(t1['signal'] == 1 , t1['supertrend'] , np.nan)
t1['sups'] = np.where(t1['signal'] == -1 , t1['supertrend'] , np.nan)

t1 = t1[1:]
t1
